# %% [markdown]
# # Project Description This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features-
#
# W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# -- Output: Number of predicted wins (W) To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %%
# Importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# let's rename the columns for understaind the data better

# %%
df.rename(columns={'W':'Wins','R':'Runs','AB':'Time at Bat','H':'Hit','2B':'Double','3B':'Triple','HR':'Home Runs','BB':'Base on Balls','SO':'Strikeout','SB':'Stolen Base','RA':'Run Avg','ER':'Earned Run','ERA':'Earned Run Avg','CG':'Complete Game','SHO':'Shutout','SV':'Save','E':'Errors'}, inplace=True)

# %%
df.tail()
# Out:
#     Wins  Runs  Time at Bat   Hit  Double  Triple  Home Runs  Base on Balls  \
# 25    92   667         5385  1346     263      26        187            563
# 26    84   696         5565  1486     288      39        136            457
# 27    79   720         5649  1494     289      48        154            490
# 28    74   650         5457  1324     260      36        148            426
# 29    68   737         5572  1479     274      49        186            388
#
#     Strikeout  Stolen Base  Run Avg  Earned Run  Earned Run Avg  \
# 25       1258           59      595         553            3.44
# 26       1159           93      627         597            3.72
# 27       1312          132      713         659            4.04
# 28       1327           82      731         655            4.09
# 29       1283           97      844         799            5.04
#
#     Complete Game  Shutout  Save  Errors
# 25              6       21    47      75
# 26              7       18    41      78
# 27              1       12    44      86
# 28              1        6    41      92
# 29              4        4    36      95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wins            30 non-null     int64
#  1   Runs            30 non-null     int64
#  2   Time at Bat     30 non-null     int64
#  3   Hit             30 non-null     int64
#  4   Double          30 non-null     int64
#  5   Triple          30 non-null     int64
#  6   Home Runs       30 non-null     int64
#  7   Base on Balls   30 non-null     int64
#  8   Strikeout       30 non-null     int64
#  9   Stolen Base     30 non-null     int64
#  10  Run Avg         30 non-null     int64
#  11  Earned Run      30 non-null     int64
#  12  Earned Run Avg  30 non-null     float64
#  13  Complete Game   30 non-null     int64
#  14  Shutout         30 non-null     int64
#  15  Save            30 non-null     int64
#  16  Errors          30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# There are 30 rows and 17 columns present in the dataset.
# Wins is our target variable.
# There are no null values present in the dataset.

# %%
df.dtypes
# Out:
# Wins                int64
# Runs                int64
# Time at Bat         int64
# Hit                 int64
# Double              int64
# Triple              int64
# Home Runs           int64
# Base on Balls       int64
# Strikeout           int64
# Stolen Base         int64
# Run Avg             int64
# Earned Run          int64
# Earned Run Avg    float64
# Complete Game       int64
# Shutout             int64
# Save                int64
# Errors              int64
# dtype: object

# %%
df['Earned Run Avg']
# Out:
# 0     3.73
# 1     4.07
# 2     3.67
# 3     3.98
# 4     4.64
# 5     3.80
# 6     4.03
# 7     4.05
# 8     3.74
# 9     4.31
# 10    4.24
# 11    3.57
# 12    3.94
# 13    4.16
# 14    4.14
# 15    2.94
# 16    3.21
# 17    3.36
# 18    4.28
# 19    4.33
# 20    3.43
# 21    3.62
# 22    4.02
# 23    4.41
# 24    4.69
# 25    3.44
# 26    3.72
# 27    4.04
# 28    4.09
# 29    5.04
# Name: Earned Run Avg, dtype: float64

# %% [markdown]
# The dataset contains int datatypes in all it's columns except for the 'Earned Run Avg' column which contains float datatype.

# %%
df.describe()
# Out:
#              Wins        Runs  Time at Bat          Hit      Double  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#           Triple   Home Runs  Base on Balls   Strikeout  Stolen Base  \
# count  30.000000   30.000000      30.000000    30.00000    30.000000
# mean   31.300000  163.633333     469.100000  1248.20000    83.500000
# std    10.452355   31.823309      57.053725   103.75947    22.815225
# min    13.000000  100.000000     375.000000   973.00000    44.000000
# 25%    23.000000  140.250000     428.250000  1157.50000    69.000000
# 50%    31.000000  158.500000     473.000000  1261.50000    83.500000
# 75%    39.000000  177.000000     501.250000  1311.50000    96.500000
# max    49.000000  232.000000     570.000000  1518.00000   134.000000
#
#           Run Avg  Earned Run  Earned Run Avg  Complete Game    Shutout  \
# count   30.000000   30.000000       30.000000      30.000000  30.000000
# mean   688.233333  635.833333        3.956333       3.466667  11.300000
# std     72.108005   70.140786        0.454089       2.763473   4.120177
# min    525.000000  478.000000        2.940000       0.000000   4.000000
# 25%    636.250000  587.250000        3.682500       1.000000   9.000000
# 50%    695.500000  644.500000        4.025000       3.000000  12.000000
# 75%    732.500000  679.250000        4.220000       5.750000  13.000000
# max    844.000000  799.000000        5.040000      11.000000  21.000000
#
#             Save      Errors
# count  30.000000   30.000000
# mean   43.066667   94.333333
# std     7.869335   13.958889
# min    28.000000   75.000000
# 25%    37.250000   86.000000
# 50%    42.000000   91.000000
# 75%    46.750000   96.750000
# max    62.000000  126.000000

# %% [markdown]
# This provides us the information about the following:-
#
# 1. Total no. of values present in the dataset
#
# 2. Mean of the columns
#
# 3. Standard deviation
#
# 4. Minimum values
#
# 5. 1st quertile
#
# 6. 2nd quertile(median)
#
# 7. 3rd qurtile
#
# 8. Maximum values

# %% [markdown]
# # Data Visualisation

# %%
cor=df.corr()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# from the above heatmap we can observe that the column 'Earned Run Avg' is highly inversaly correlated with the target variable 'Wins'.
#
# Features like 'Run Avg', 'Earned Run' and 'Earned RUn Evg' are  also highly correlated with each other.
#
# We will remove some features to avoid multicollinearity problem.

# %%
df=df.drop(columns=['Earned Run Avg'])

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar',subplots=True,layout=(6,3),figsize=(16,16))
plt.show()

# %% [markdown]
# Let's seperate features and label

# %%
x=df.drop(columns=['Wins'])
y=df['Wins']

# %%
plt.figure(figsize=(20,25),facecolor='lightblue')
pltno=1

for a in x:
    if pltno<=16:
        ax=plt.subplot(6,3,pltno)
        sns.regplot(x=a,y=y,data=df,color='blue')
        plt.xlabel(a,fontsize=16)
        
    pltno+=1

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(26,23),facecolor='lightyellow')
pltn=1
for a in df:
    if pltn<=16:
        ax=plt.subplot(6,3,pltn)
        sns.distplot(df[a],color='brown')
        plt.xlabel(a,fontsize=16)
    pltn+=1

# %% [markdown]
# there is skewness present in some of the features

# %%
df.skew()
# Out:
# Wins             0.047089
# Runs             1.200786
# Time at Bat      0.183437
# Hit              0.670254
# Double          -0.230650
# Triple           0.129502
# Home Runs        0.516441
# Base on Balls    0.158498
# Strikeout       -0.156065
# Stolen Base      0.479893
# Run Avg          0.045734
# Earned Run       0.058710
# Complete Game    0.736845
# Shutout          0.565790
# Save             0.657524
# Errors           0.890132
# dtype: float64

# %% [markdown]
#  First let's look if there are outliers present in the dataset

# %%
plt.figure(figsize=(26,23),facecolor='lightblue')
pltn=1
for a in df:
    if pltn<=16:
        ax=plt.subplot(6,3,pltn)
        sns.boxplot(df[a])
        plt.xlabel(a, fontsize=14)
    pltn+=1

# %% [markdown]
# There are some outliers present in the dataset

# %% [markdown]
# # Remove the outliers.

# %%
from scipy.stats import zscore
import numpy as np

z=np.abs(zscore(df))

z.shape
# Out:
# (30, 16)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1
# Out:
#     Wins  Runs  Time at Bat   Hit  Double  Triple  Home Runs  Base on Balls  \
# 0     95   724         5575  1497     300      42        139            383
# 1     83   696         5467  1349     277      44        156            439
# 2     81   669         5439  1395     303      29        141            533
# 3     76   622         5533  1381     260      27        136            404
# 4     74   689         5605  1515     289      49        151            455
# 6     87   764         5567  1397     272      19        212            554
# 7     81   713         5485  1370     246      20        217            418
# 8     80   644         5485  1383     278      32        167            436
# 9     78   748         5640  1495     294      33        161            478
# 10    88   751         5511  1419     279      32        172            503
# 11    86   729         5459  1363     278      26        230            486
# 12    85   661         5417  1331     243      21        176            435
# 13    76   656         5544  1379     262      22        198            478
# 14    68   694         5600  1405     277      46        146            475
# 15   100   647         5484  1386     288      39        137            506
# 16    98   697         5631  1462     292      27        140            461
# 17    97   689         5491  1341     272      30        171            567
# 18    68   655         5480  1378     274      34        145            412
# 19    64   640         5571  1382     257      27        167            496
# 20    90   683         5527  1351     295      17        177            488
# 21    83   703         5428  1363     265      13        177            539
# 22    71   613         5463  1420     236      40        120            375
# 23    67   573         5420  1361     251      18        100            471
# 24    63   626         5529  1374     272      37        130            387
# 25    92   667         5385  1346     263      26        187            563
# 26    84   696         5565  1486     288      39        136            457
# 27    79   720         5649  1494     289      48        154            490
# 28    74   650         5457  1324     260      36        148            426
# 29    68   737         5572  1479     274      49        186            388
#
#     Strikeout  Stolen Base  Run Avg  Earned Run  Complete Game  Shutout  Save  \
# 0         973          104      641         601              2        8    56
# 1        1264           70      700         653              2       12    45
# 2        1157           86      640         584             11       10    38
# 3        1231           68      701         643              7        9    37
# 4        1259           83      803         746              7       12    35
# 6        1227           63      698         652              3        4    48
# 7        1331           44      693         646              0       10    43
# 8        1310           87      642         604              1       12    60
# 9        1148           71      753         694              3       10    40
# 10       1233          101      733         680              5        9    45
# 11       1392          121      618         572              5       13    39
# 12       1150           52      675         630              2       12    46
# 13       1336           69      726         677              6       12    45
# 14       1119           78      729         664              5       15    28
# 15       1267           69      525         478              1       15    62
# 16       1322           98      596         532              0       13    54
# 17       1518           95      608         546              6       21    48
# 18       1299           84      737         682              1        7    40
# 19       1255          134      754         700              2        8    35
# 20       1290           51      613         557              1       14    50
# 21       1344           57      635         577              4       13    41
# 22       1150          112      678         638              0       12    35
# 23       1107           69      760         698              3       10    44
# 24       1274           88      809         749              1        7    35
# 25       1258           59      595         553              6       21    47
# 26       1159           93      627         597              7       18    41
# 27       1312          132      713         659              1       12    44
# 28       1327           82      731         655              1        6    41
# 29       1283           97      844         799              4        4    36
#
#     Errors
# 0       88
# 1       86
# 2       79
# 3      101
# 4       86
# 6       93
# 7       77
# 8       95
# 9       97
# 10     119
# 11      85
# 12      93
# 13      94
# 14     126
# 15      96
# 16     122
# 17     111
# 18     116
# 19      90
# 20      88
# 21      90
# 22      77
# 23      90
# 24     117
# 25      75
# 26      78
# 27      86
# 28      92
# 29      95

# %%
df1.shape
# Out:
# (29, 16)

# %% [markdown]
# Outliers have been removed from the dataset

# %%
x=df1.drop(columns=['Wins'])
y=df1['Wins']

# %%
x.skew()
# Out:
# Runs            -0.215364
# Time at Bat      0.169573
# Hit              0.783772
# Double          -0.335304
# Triple           0.090124
# Home Runs        0.450862
# Base on Balls    0.151193
# Strikeout       -0.233815
# Stolen Base      0.494966
# Run Avg          0.018155
# Earned Run       0.018461
# Complete Game    0.854980
# Shutout          0.526943
# Save             0.627480
# Errors           0.840271
# dtype: float64

# %% [markdown]
# As we can observe that there are still some features which have skewness present in them after removing the outliers, so we will fix the skewness now.
#
# The acceptable skewness range is -0.5 to +0.5.

# %%
x['Hit']=np.log1p(x['Hit'])
x['Complete Game']=np.log1p(x['Complete Game'])
x['Save']=np.log1p(x['Save'])
x['Errors']=np.log1p(x['Errors'])

# %%
x.skew()
# Out:
# Runs            -0.215364
# Time at Bat      0.169573
# Hit              0.738455
# Double          -0.335304
# Triple           0.090124
# Home Runs        0.450862
# Base on Balls    0.151193
# Strikeout       -0.233815
# Stolen Base      0.494966
# Run Avg          0.018155
# Earned Run       0.018461
# Complete Game   -0.275681
# Shutout          0.526943
# Save             0.109983
# Errors           0.586101
# dtype: float64

# %%
x
# Out:
#     Runs  Time at Bat       Hit  Double  Triple  Home Runs  Base on Balls  \
# 0    724         5575  7.311886     300      42        139            383
# 1    696         5467  7.207860     277      44        156            439
# 2    669         5439  7.241366     303      29        141            533
# 3    622         5533  7.231287     260      27        136            404
# 4    689         5605  7.323831     289      49        151            455
# 6    764         5567  7.242798     272      19        212            554
# 7    713         5485  7.223296     246      20        217            418
# 8    644         5485  7.232733     278      32        167            436
# 9    748         5640  7.310550     294      33        161            478
# 10   751         5511  7.258412     279      32        172            503
# 11   729         5459  7.218177     278      26        230            486
# 12   661         5417  7.194437     243      21        176            435
# 13   656         5544  7.229839     262      22        198            478
# 14   694         5600  7.248504     277      46        146            475
# 15   647         5484  7.234898     288      39        137            506
# 16   697         5631  7.288244     292      27        140            461
# 17   689         5491  7.201916     272      30        171            567
# 18   655         5480  7.229114     274      34        145            412
# 19   640         5571  7.232010     257      27        167            496
# 20   683         5527  7.209340     295      17        177            488
# 21   703         5428  7.218177     265      13        177            539
# 22   613         5463  7.259116     236      40        120            375
# 23   573         5420  7.216709     251      18        100            471
# 24   626         5529  7.226209     272      37        130            387
# 25   667         5385  7.205635     263      26        187            563
# 26   696         5565  7.304516     288      39        136            457
# 27   720         5649  7.309881     289      48        154            490
# 28   650         5457  7.189168     260      36        148            426
# 29   737         5572  7.299797     274      49        186            388
#
#     Strikeout  Stolen Base  Run Avg  Earned Run  Complete Game  Shutout  \
# 0         973          104      641         601       1.098612        8
# 1        1264           70      700         653       1.098612       12
# 2        1157           86      640         584       2.484907       10
# 3        1231           68      701         643       2.079442        9
# 4        1259           83      803         746       2.079442       12
# 6        1227           63      698         652       1.386294        4
# 7        1331           44      693         646       0.000000       10
# 8        1310           87      642         604       0.693147       12
# 9        1148           71      753         694       1.386294       10
# 10       1233          101      733         680       1.791759        9
# 11       1392          121      618         572       1.791759       13
# 12       1150           52      675         630       1.098612       12
# 13       1336           69      726         677       1.945910       12
# 14       1119           78      729         664       1.791759       15
# 15       1267           69      525         478       0.693147       15
# 16       1322           98      596         532       0.000000       13
# 17       1518           95      608         546       1.945910       21
# 18       1299           84      737         682       0.693147        7
# 19       1255          134      754         700       1.098612        8
# 20       1290           51      613         557       0.693147       14
# 21       1344           57      635         577       1.609438       13
# 22       1150          112      678         638       0.000000       12
# 23       1107           69      760         698       1.386294       10
# 24       1274           88      809         749       0.693147        7
# 25       1258           59      595         553       1.945910       21
# 26       1159           93      627         597       2.079442       18
# 27       1312          132      713         659       0.693147       12
# 28       1327           82      731         655       0.693147        6
# 29       1283           97      844         799       1.609438        4
#
#         Save    Errors
# 0   4.043051  4.488636
# 1   3.828641  4.465908
# 2   3.663562  4.382027
# 3   3.637586  4.624973
# 4   3.583519  4.465908
# 6   3.891820  4.543295
# 7   3.784190  4.356709
# 8   4.110874  4.564348
# 9   3.713572  4.584967
# 10  3.828641  4.787492
# 11  3.688879  4.454347
# 12  3.850148  4.543295
# 13  3.828641  4.553877
# 14  3.367296  4.844187
# 15  4.143135  4.574711
# 16  4.007333  4.812184
# 17  3.891820  4.718499
# 18  3.713572  4.762174
# 19  3.583519  4.510860
# 20  3.931826  4.488636
# 21  3.737670  4.510860
# 22  3.583519  4.356709
# 23  3.806662  4.510860
# 24  3.583519  4.770685
# 25  3.871201  4.330733
# 26  3.737670  4.369448
# 27  3.806662  4.465908
# 28  3.737670  4.532599
# 29  3.610918  4.564348

# %% [markdown]
# Now let's standardise the data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaledx=sc.fit_transform(x)
scaledx
# Out:
# array([[ 0.95939835,  0.83008422,  1.72372599,  1.55653766,  1.01084549,
#         -0.76586314, -1.53635899, -2.72762331,  0.9059529 , -0.66451353,
#         -0.51114812, -0.24041455, -0.81326172,  1.55481209, -0.43573324],
#        [ 0.33114717, -0.70283074, -0.94984589,  0.20117132,  1.20891656,
#         -0.18138864, -0.49502051,  0.12189552, -0.58531515,  0.15463823,
#          0.23216082, -0.24041455,  0.15929869,  0.29622875, -0.59810993],
#        [-0.27466646, -1.10025314, -0.08870013,  1.73332457, -0.2766165 ,
#         -0.69710144,  1.25294051, -0.9258657 ,  0.11645805, -0.67839746,
#         -0.75415297,  1.81571095, -0.32698152, -0.67278738, -1.19738162],
#        [-1.32923093,  0.23395062, -0.34774692, -0.8006212 , -0.47468758,
#         -0.8690057 , -1.14585706, -0.20124579, -0.6730368 ,  0.16852216,
#          0.08921679,  1.21433279, -0.57012162, -0.82526317,  0.53829069],
#        [ 0.17408438,  1.25589393,  2.03070817,  0.90831897,  1.70409425,
#         -0.35329291, -0.19749523,  0.07293472, -0.01512442,  1.58468284,
#          1.56154027,  1.21433279,  0.15929869, -1.14263711, -0.59810993],
#        [ 1.85690002,  0.71653496, -0.05190567, -0.09347354, -1.26697188,
#          1.74393914,  1.64344245, -0.24041443, -0.89234092,  0.12687038,
#          0.21786641,  0.18627005, -1.78582213,  0.66708814, -0.04523896],
#        [ 0.71258538, -0.44734492, -0.55313135, -1.6256268 , -1.16793634,
#          1.9158434 , -0.88552244,  0.7779703 , -1.7256966 ,  0.05745074,
#          0.1321    , -1.86985545, -0.32698152,  0.03529744, -1.3782588 ],
#        [-0.83560501, -0.44734492, -0.31057999,  0.26010029,  0.02049011,
#          0.19680075, -0.5508065 ,  0.57233492,  0.16031888, -0.6506296 ,
#         -0.46826492, -0.8417927 ,  0.15929869,  1.95292991,  0.10517222],
#        [ 1.49789935,  1.75267193,  1.68938942,  1.20296383,  0.11952565,
#         -0.00948437,  0.23019736, -1.01399515, -0.54145432,  0.89048643,
#          0.81823133,  0.18627005, -0.32698152, -0.37922682,  0.2524819 ],
#        [ 1.56521198, -0.07830983,  0.34939441,  0.31902926,  0.02049011,
#          0.36870501,  0.69508061, -0.18166147,  0.77437043,  0.61280787,
#          0.61810969,  0.7876482 , -0.57012162,  0.29622875,  1.69936927],
#        [ 1.07158606, -0.81638   , -0.6846903 ,  0.26010029, -0.57372311,
#          2.3627945 ,  0.37896   ,  1.37529212,  1.65158693, -0.98384388,
#         -0.9256858 ,  0.7876482 ,  0.40243879, -0.52417216, -0.68070352],
#        [-0.4541668 , -1.4125136 , -1.29482992, -1.80241371, -1.0689008 ,
#          0.50622842, -0.56940183, -0.99441083, -1.37481   , -0.19245997,
#         -0
#
#     Complete Game   Shutout      Save    Errors
# 0       -0.240415 -0.813262  1.554812 -0.435733
# 1       -0.240415  0.159299  0.296229 -0.598110
# 2        1.815711 -0.326982 -0.672787 -1.197382
# 3        1.214333 -0.570122 -0.825263  0.538291
# 4        1.214333  0.159299 -1.142637 -0.598110
# 5        0.186270 -1.785822  0.667088 -0.045239
# 6       -1.869855 -0.326982  0.035297 -1.378259
# 7       -0.841793  0.159299  1.952930  0.105172
# 8        0.186270 -0.326982 -0.379227  0.252482
# 9        0.787648 -0.570122  0.296229  1.699369
# 10       0.787648  0.402439 -0.524172 -0.680704
# 11      -0.240415  0.159299  0.422470 -0.045239
# 12       1.016282  0.159299  0.296229  0.030362
# 13       0.787648  0.888719 -2.411864  2.104416
# 14      -0.841793  0.888719  2.142301  0.179207
# 15      -1.869855  0.402439  1.345147  1.875780
# 16       1.016282  2.347560  0.667088  1.206466
# 17      -0.841793 -1.056402 -0.379227  1.518492
# 18      -0.240415 -0.813262 -1.142637 -0.276965
# 19      -0.841793  0.645579  0.901919 -0.435733
# 20       0.517232  0.402439 -0.237774 -0.276965
# 21      -1.869855  0.159299 -1.142637 -1.378259
# 22       0.186270 -0.326982  0.167213 -0.276965
# 23      -0.841793 -1.056402 -1.142637  1.579295
# 24       1.016282  2.347560  0.546053 -1.563835
# 25       1.214333  1.618139 -0.237774 -1.287248
# 26      -0.841793  0.159299  0.167213 -0.598110
# 27      -0.841793 -1.299542 -0.237774 -0.121649
# 28       0.517232 -1.785822 -0.981805  0.105172

# %% [markdown]
# Now let's check for the multicollinearity using vif

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Vif values']=[variance_inflation_factor(xx.values,i) for i in range(len(xx.columns))]
vif["features"]=xx.columns

# %%
vif
# Out:
#     Vif values       features
# 0     6.260622           Runs
# 1     5.147283    Time at Bat
# 2     8.224993            Hit
# 3     3.416409         Double
# 4     3.302034         Triple
# 5     8.210585      Home Runs
# 6     3.442913  Base on Balls
# 7     2.884465      Strikeout
# 8     1.872449    Stolen Base
# 9   189.398030        Run Avg
# 10  183.809924     Earned Run
# 11    2.566495  Complete Game
# 12    3.551622        Shutout
# 13    2.865864           Save
# 14    2.114024         Errors

# %% [markdown]
# Columns 'Run Avg' and "Earned run" have very high vif values
#
# Let's try removing one of the feature

# %%
xx=xx.drop(columns=['Run Avg'])

# %%
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(xx.values,i) for i in range(len(xx.columns))]
vif['features']=xx.columns

# %%
vif
# Out:
#     vif values       features
# 0     6.078210           Runs
# 1     4.793313    Time at Bat
# 2     7.436780            Hit
# 3     3.353686         Double
# 4     3.215841         Triple
# 5     6.262683      Home Runs
# 6     3.147563  Base on Balls
# 7     2.272100      Strikeout
# 8     1.765989    Stolen Base
# 9     4.881683     Earned Run
# 10    2.529041  Complete Game
# 11    3.261136        Shutout
# 12    2.282187           Save
# 13    2.046866         Errors

# %% [markdown]
# Now the vif values of  all the features are below 10 so we can proceed further.

# %%
y.nunique()
# Out:
# 23

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: Wins, dtype: int64

# %% [markdown]
# There are total 23 unique values out of 29 values present in the target varaible, so regression model should be built for this

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, r2_score

# %%
xx.head()
# Out:
#        Runs  Time at Bat       Hit    Double    Triple  Home Runs  \
# 0  0.959398     0.830084  1.723726  1.556538  1.010845  -0.765863
# 1  0.331147    -0.702831 -0.949846  0.201171  1.208917  -0.181389
# 2 -0.274666    -1.100253 -0.088700  1.733325 -0.276617  -0.697101
# 3 -1.329231     0.233951 -0.347747 -0.800621 -0.474688  -0.869006
# 4  0.174084     1.255894  2.030708  0.908319  1.704094  -0.353293
#
#    Base on Balls  Strikeout  Stolen Base  Earned Run  Complete Game   Shutout  \
# 0      -1.536359  -2.727623     0.905953   -0.511148      -0.240415 -0.813262
# 1      -0.495021   0.121896    -0.585315    0.232161      -0.240415  0.159299
# 2       1.252941  -0.925866     0.116458   -0.754153       1.815711 -0.326982
# 3      -1.145857  -0.201246    -0.673037    0.089217       1.214333 -0.570122
# 4      -0.197495   0.072935    -0.015124    1.561540       1.214333  0.159299
#
#        Save    Errors
# 0  1.554812 -0.435733
# 1  0.296229 -0.598110
# 2 -0.672787 -1.197382
# 3 -0.825263  0.538291
# 4 -1.142637 -0.598110

# %%
maxAcc=0
maxRS=0

for i in range(1,50):
    xtrain,xtest,ytrain,ytest=train_test_split(xx,y,test_size=.25,random_state=i)
    lg=LinearRegression()
    lg.fit(xtrain,ytrain)
    pred=lg.predict(xtest)
    acc=r2_score(ytest,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print('best accuracy is:-',maxAcc,'on random state:-',maxRS)
# Out:
# best accuracy is:- 0.9322833863666629 on random state:- 47

# %% [markdown]
# Best random state is 47

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xx,y,test_size=.25,random_state=47)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
lr=LinearRegression()
lr.fit(xtrain,ytrain)
lp=lr.predict(xtest)
print(r2_score(ytest,lp))
print('mean squared error:',mean_squared_error(ytest,lp))
print('mean absolute error:',mean_absolute_error(ytest,lp))
# Out:
# 0.9322833863666629
# mean squared error: 8.409556955590052
# mean absolute error: 2.3334173531286844

# %%
# RANDOMFOREST REGRESSOR

r=RandomForestRegressor()
r.fit(xtrain,ytrain)
rp=r.predict(xtest)
print(r2_score(ytest,rp))
print('mean squared error:', mean_squared_error(ytest,lp))
print('mean absolute error:', mean_absolute_error(ytest,lp))
# Out:
# 0.6543026673376948
# mean squared error: 8.409556955590052
# mean absolute error: 2.3334173531286844

# %%
# ADABOOST REGRESSOR

a=AdaBoostRegressor()
a.fit(xtrain,ytrain)
ap=a.predict(xtest)
print(r2_score(ytest,ap))
print('mean squared error:',mean_squared_error(ytest,ap))
print('mean absolute error:', mean_absolute_error(ytest,ap))
# Out:
# 0.5779032849323068
# mean squared error: 52.41913580246915
# mean absolute error: 6.505555555555556

# %%
# DECISIONTREE REGRESSOR
d= DecisionTreeRegressor()
d.fit(xtrain,ytrain)
dp=d.predict(xtest)
print(r2_score(ytest,dp))
print('mean squared error:', mean_squared_error(ytest,dp))
print('mean absolute error:', mean_absolute_error(ytest,dp))
# Out:
# 0.5188726723704076
# mean squared error: 59.75
# mean absolute error: 6.25

# %%
# SVR

ss=SVR()
ss.fit(xtrain,ytrain)
sp=ss.predict(xtest)
print(r2_score(ytest,sp))
print('mean squared error:', mean_squared_error(ytest,sp))
print('mean babsolute error:', mean_absolute_error(ytest,sp))
# Out:
# 0.03432141389144061
# mean squared error: 119.92520941235672
# mean babsolute error: 9.311877121374522

# %%
#KNEIGHBORS REGRESSOR

k=KNeighborsRegressor()
k.fit(xtrain,ytrain)
kp=k.predict(xtest)
print(r2_score(ytest,kp))
print('mean squared error:', mean_squared_error(ytest,kp))
print('mean absolute error:', mean_absolute_error(ytest,kp))
# Out:
# 0.450427780573729
# mean squared error: 68.25000000000003
# mean absolute error: 6.600000000000001

# %% [markdown]
# # CrossValidation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# LINEAR REGRESSION

s=cross_val_score(lr,xx,y)
print(s)
print(s.mean())
# Out:
# [ 0.36333663 -0.80543522  0.62281389  0.6178925   0.68401163]
# 0.2965238860393435

# %%
# RANDOMFOREST REGRESSOR

s=cross_val_score(r,xx,y)
print(s)
print(s.mean())
# Out:
# [ 0.15620705 -4.72110132  0.40656587  0.35583475  0.79203007]
# -0.6020927146923538

# %%
# DECISIONTREE REGRESSOR

s=cross_val_score(d,xx,y)
print(s)
print(s.mean())
# Out:
# [-1.45795455 -9.94736842  0.09744877  0.22786885 -0.49174528]
# -2.3143501261720845

# %%
# ADABOOST REGRESSOR

s=cross_val_score(a,xx,y)
print(s)
print(s.mean())
# Out:
# [ 0.21379677 -4.97226283  0.36964148  0.52957366  0.74486774]
# -0.6228766385526276

# %%
# SVR

s=cross_val_score(ss,xx,y)
print(s)
print(s.mean())
# Out:
# [-0.08976601 -1.18031568 -0.01718593 -0.45909798  0.16614873]
# -0.3160433763118902

# %%
# KNEIGHBORS REGRESSOR
s=cross_val_score(k,xx,y)
print(s)
print(s.mean())
# Out:
# [-0.07413636 -1.99842105  0.422133    0.27088525  0.77216981]
# -0.1214738720600506

# %% [markdown]
#  Observing the crossvalidation score of each model, we can see that linearregression model is the best model of them all

# %%
# PREDICTING VALLUES

dd=pd.DataFrame({'Predicted values':lp,'Actual values':ytest})

# %%
dd
# Out:
#     Predicted values  Actual values
# 15         96.491678            100
# 3          71.354275             76
# 28         72.750262             74
# 11         85.593835             86
# 13         75.767071             76
# 19         62.828817             64
# 0          90.164992             95
# 6          84.381730             87

# %% [markdown]
# # BEST FIT LINE

# %%
plt.scatter(x=ytest,y=lp, color='red')
plt.plot(ytest,ytest,color='green')
plt.title('Best Fit Line',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Best Fit Line')

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(lr,'Baseball_prediction')
# Out:
# ['Baseball_prediction']

# %% [markdown]
# # Loading the Model

# %%
p=joblib.load('Baseball_prediction')
q=p.predict(xtest)
print(q)
# Out:
# [96.49167786 71.35427543 72.75026202 85.59383524 75.7670712  62.82881652
#  90.16499249 84.38173041]

# %%
d=pd.DataFrame({'predicted values':q,'actual values':ytest})

# %%
d
# Out:
#     predicted values  actual values
# 15         96.491678            100
# 3          71.354275             76
# 28         72.750262             74
# 11         85.593835             86
# 13         75.767071             76
# 19         62.828817             64
# 0          90.164992             95
# 6          84.381730             87
