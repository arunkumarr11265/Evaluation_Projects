# %% [markdown]
# # Project Description:-
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best cuisines of every part of the world which lies in their budget. This analysis is also for those who want to find the value for money restaurants in various parts of the country for the cuisines. Additionally, this analysis caters the needs of people who are striving to get the best cuisine of the country and which locality of that country serves that cuisines with maximum number of restaurants.
#
# Data Storage: This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
# Country_code.csv contains two variables: • Country code • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant's location
#
# • Latitude: Latitude coordinate of the restaurant's location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people
#
# Problem statement : In this dataset predict 2 things –
#
# 1) Average Cost for two
#
# 2) Price range
#
# Hint : Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets
#
# Dataset Link-
# • https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
#
# • https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
# Import the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import  warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_excel(r'C:\Users\arunk\Downloads\Country-Code.xlsx')

# %%
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv', encoding='latin-1')

# %%
df2.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df=pd.merge (df1,df2)

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# There are total of 9551 rows and 22 columns present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %% [markdown]
# There are no null values present in the dataset

# %%
for q in df.columns:
    print(df[q].value_counts())
    print('\n','*'*94)
# Out:
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#  **********************************************************************************************
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
#
#  **********************************************************************************************
# 3400025     1
# 309811      1
# 18460981    1
# 18287389    1
# 1629        1
#            ..
# 4096        1
# 18358700    1
# 2217        1
# ...

# %%
df.isin([' ?','-',' ']).sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID             int64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values present in the dataset.

# %%
cc=[]
nn=[]

for c in df.dtypes.index:
    if df.dtypes[c]=='object':
        cc.append(c)
    else:
        nn.append(c)

# %%
cc
# Out:
# ['Country',
#  'Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text']

# %%
nn
# Out:
# ['Country Code',
#  'Restaurant ID',
#  'Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
for i in cc:
    print ("\033[1m"+i+"\033[0m")
    print(df[i].value_counts())
    print('*'*75)
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
# ***************************************************************************
# Restaurant Name
# Cafe Coffee Day                       83
# Domino's Pizza                        79
# Subway                                63
# Green Chick Chop                      51
# McDonald's                            48
#                                       ..
# Chor Bizarre - Hotel Broadway          1
# Thugs - Hotel Broadway                 1
# The Kylin Experience - Holiday Inn     1
# Cafe on 3 - Holiday Inn                1
# Fishpatrick's Crabby Cafe              1
# ...

# %% [markdown]
# Columns like 'address' have too many unique values considering it has object datatype.
#
# Columns locality and locality verbose contains same kind of data with locality verbose having extra irrelevent data.
#
# Columns country and country code are basically same data.
#
# Column switch to order manu have only one value
#
# Columns rating and rating color are basically the same kind of data.
#
# Column is delivering now basically just shows the availability of delivering the order. It is not important for model building.
#
#
#
#
#
# So we will be dropping these columns.

# %%
df.drop(columns=['Switch to order menu','Address','Locality Verbose','Is delivering now','Switch to order menu','Rating color','Country Code','City'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9551 non-null   object
#  1   Restaurant ID         9551 non-null   int64
#  2   Restaurant Name       9551 non-null   object
#  3   Locality              9551 non-null   object
#  4   Longitude             9551 non-null   float64
#  5   Latitude              9551 non-null   float64
#  6   Cuisines              9542 non-null   object
#  7   Average Cost for two  9551 non-null   int64
#  8   Currency              9551 non-null   object
#  9   Has Table booking     9551 non-null   object
#  10  Has Online delivery   9551 non-null   object
#  11  Price range           9551 non-null   int64
#  12  Aggregate rating      9551 non-null   float64
#  13  Rating text           9551 non-null   object
#  14  Votes                 9551 non-null   int64
# ...

# %%
df.nunique()
# Out:
# Country                   15
# Restaurant ID           9551
# Restaurant Name         7446
# Locality                1208
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Price range                4
# Aggregate rating          33
# Rating text                6
# Votes                   1012
# dtype: int64

# %% [markdown]
# Column restaurant ID have only unique values present in them considering it has int datatype present in it.
#
#
# column restaurant Name also have major unique value present in it witch object datatype.

# %%
df=df.drop(columns=['Restaurant ID','Restaurant Name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9551 non-null   object
#  1   Locality              9551 non-null   object
#  2   Longitude             9551 non-null   float64
#  3   Latitude              9551 non-null   float64
#  4   Cuisines              9542 non-null   object
#  5   Average Cost for two  9551 non-null   int64
#  6   Currency              9551 non-null   object
#  7   Has Table booking     9551 non-null   object
#  8   Has Online delivery   9551 non-null   object
#  9   Price range           9551 non-null   int64
#  10  Aggregate rating      9551 non-null   float64
#  11  Rating text           9551 non-null   object
#  12  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.0+ MB

# %%
df
# Out:
#             Country        Locality   Longitude   Latitude  \
# 0             India      Agra Cantt   78.011544  27.161661
# 1             India      Agra Cantt    0.000000   0.000000
# 2             India      Agra Cantt   78.011608  27.160832
# 3             India     Civil Lines   77.998092  27.195928
# 4             India     Civil Lines   78.007553  27.201725
# ...             ...             ...         ...        ...
# 9546  United States        Waterloo  -92.335523  42.498400
# 9547  United States        Waterloo  -92.335769  42.497919
# 9548  United States        Waterloo  -92.323400  42.465580
# 9549  United States         Weirton  -80.529488  40.396043
# 9550  United States  Winchester Bay -124.175346  43.678998
#
#                             Cuisines  Average Cost for two  \
# 0              North Indian, Mughlai                   850
# 1              North Indian, Mughlai                   700
# 2                       North Indian                   500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9551 non-null   object
#  1   Locality              9551 non-null   object
#  2   Longitude             9551 non-null   float64
#  3   Latitude              9551 non-null   float64
#  4   Cuisines              9542 non-null   object
#  5   Average Cost for two  9551 non-null   int64
#  6   Currency              9551 non-null   object
#  7   Has Table booking     9551 non-null   object
#  8   Has Online delivery   9551 non-null   object
#  9   Price range           9551 non-null   int64
#  10  Aggregate rating      9551 non-null   float64
#  11  Rating text           9551 non-null   object
#  12  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.0+ MB

# %%
df.isna().sum()
# Out:
# Country                 0
# Locality                0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Country                 0
# Locality                0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9542 non-null   object
#  1   Locality              9542 non-null   object
#  2   Longitude             9542 non-null   float64
#  3   Latitude              9542 non-null   float64
#  4   Cuisines              9542 non-null   object
#  5   Average Cost for two  9542 non-null   int64
#  6   Currency              9542 non-null   object
#  7   Has Table booking     9542 non-null   object
#  8   Has Online delivery   9542 non-null   object
#  9   Price range           9542 non-null   int64
#  10  Aggregate rating      9542 non-null   float64
#  11  Rating text           9542 non-null   object
#  12  Votes                 9542 non-null   int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#          Longitude     Latitude  Average Cost for two  Price range  \
# count  9542.000000  9542.000000           9542.000000  9542.000000
# mean     64.274997    25.848532           1200.326137     1.804968
# std      41.197602    11.010094          16128.743876     0.905563
# min    -157.948486   -41.330428              0.000000     1.000000
# 25%      77.081565    28.478658            250.000000     1.000000
# 50%      77.192031    28.570444            400.000000     2.000000
# 75%      77.282043    28.642711            700.000000     2.000000
# max     174.832089    55.976980         800000.000000     4.000000
#
#        Aggregate rating         Votes
# count       9542.000000   9542.000000
# mean           2.665238    156.772060
# std            1.516588    430.203324
# min            0.000000      0.000000
# 25%            2.500000      5.000000
# 50%            3.200000     31.000000
# 75%            3.700000    130.000000
# max            4.900000  10934.000000

# %%
df.describe(include='object')
# Out:
#        Country         Locality      Cuisines            Currency  \
# count     9542             9542          9542                9542
# unique      15             1206          1825                  12
# top      India  Connaught Place  North Indian  Indian Rupees(Rs.)
# freq      8652              122           936                8652
#
#        Has Table booking Has Online delivery Rating text
# count               9542                9542        9542
# unique                 2                   2           6
# top                   No                  No     Average
# freq                8384                7091        3734

# %% [markdown]
# There may be skewness present in the dataset as the mean values and median(50%) values data noticable difference present in them.
#
# there might be outliers present in them as the 75% value and max vaalue have difference in them.

# %%
int_cols=[]
for i in  df.dtypes.index:
    if df.dtypes[i]!=object:
        int_cols.append(i)
        
obj_cols=[]
for i in df.dtypes.index:
    if df.dtypes[i]==object :
        obj_cols.append(i)

# %%
obj_cols
# Out:
# ['Country',
#  'Locality',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Rating text']

# %%
int_cols
# Out:
# ['Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(30,30))
sns.set(font_scale=1.2)
p=1
q=1
for i in obj_cols[3:]:
    if p<=7:
        ax=plt.subplot(3,3,p)
        sns.countplot(x=df[i],palette='twilight_shifted')
        plt.xticks(rotation=90)
        p+=1
plt.tight_layout()

# %%
int_cols
# Out:
# ['Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
p=1
plt.figure(figsize=(15,6))
sns.set(font_scale=1)
for i in int_cols[3:]:
    if p<=3:
        ax=plt.subplot(1,3,p)
        sns.regplot(x='Average Cost for two',y=df[i],scatter_kws=dict(color='y'),line_kws=dict(color='b'),data=df)
        plt.xticks(rotation=90)
        p+=1
plt.tight_layout()

# %%
plt.figure(figsize=(13,13),facecolor='lightyellow')
pltn=1
for col in int_cols:
    if pltn<=6:
        ax=plt.subplot(3,2,pltn)
        sns.distplot(df[col],color='brown')
        plt.xlabel(col,fontsize=15)
    pltn+=1
plt.tight_layout()

# %% [markdown]
# # Encoding

# %%
df.dtypes
# Out:
# Country                  object
# Locality                 object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Price range               int64
# Aggregate rating        float64
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df
# Out:
#             Country        Locality   Longitude   Latitude  \
# 0             India      Agra Cantt   78.011544  27.161661
# 1             India      Agra Cantt    0.000000   0.000000
# 2             India      Agra Cantt   78.011608  27.160832
# 3             India     Civil Lines   77.998092  27.195928
# 4             India     Civil Lines   78.007553  27.201725
# ...             ...             ...         ...        ...
# 9546  United States        Waterloo  -92.335523  42.498400
# 9547  United States        Waterloo  -92.335769  42.497919
# 9548  United States        Waterloo  -92.323400  42.465580
# 9549  United States         Weirton  -80.529488  40.396043
# 9550  United States  Winchester Bay -124.175346  43.678998
#
#                             Cuisines  Average Cost for two  \
# 0              North Indian, Mughlai                   850
# 1              North Indian, Mughlai                   700
# 2                       North Indian                   500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9542 non-null   object
#  1   Locality              9542 non-null   object
#  2   Longitude             9542 non-null   float64
#  3   Latitude              9542 non-null   float64
#  4   Cuisines              9542 non-null   object
#  5   Average Cost for two  9542 non-null   int64
#  6   Currency              9542 non-null   object
#  7   Has Table booking     9542 non-null   object
#  8   Has Online delivery   9542 non-null   object
#  9   Price range           9542 non-null   int64
#  10  Aggregate rating      9542 non-null   float64
#  11  Rating text           9542 non-null   object
#  12  Votes                 9542 non-null   int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.0+ MB

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()

# %%
for i in obj_cols:
    df[i]=oe.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Country  Locality   Longitude   Latitude  Cuisines  \
# 0         3.0      17.0   78.011544  27.161661    1514.0
# 1         3.0      17.0    0.000000   0.000000    1514.0
# 2         3.0      17.0   78.011608  27.160832    1306.0
# 3         3.0     204.0   77.998092  27.195928    1645.0
# 4         3.0     204.0   78.007553  27.201725    1373.0
# ...       ...       ...         ...        ...       ...
# 9546     14.0    1172.0  -92.335523  42.498400      18.0
# 9547     14.0    1172.0  -92.335769  42.497919    1795.0
# 9548     14.0    1172.0  -92.323400  42.465580    1125.0
# 9549     14.0    1174.0  -80.529488  40.396043     317.0
# 9550     14.0    1184.0 -124.175346  43.678998     327.0
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                      850       4.0                0.0                  0.0
# 1                      700       4.0                0.0                  0.0
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),cmap='twilight',annot=True)
# Out:
# <AxesSubplot:>

# %%
df=df.drop(columns=['Longitude','Latitude'])

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,20),facecolor='lightyellow')
pltno=1

for c in df:
    if pltno<=12:
        ax=plt.subplot(3,5,pltno)
        sns.distplot(df[c],color='brown')
        plt.xlabel(c,fontsize=15)
        
    pltno+=1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9542 non-null   float64
#  1   Locality              9542 non-null   float64
#  2   Cuisines              9542 non-null   float64
#  3   Average Cost for two  9542 non-null   int64
#  4   Currency              9542 non-null   float64
#  5   Has Table booking     9542 non-null   float64
#  6   Has Online delivery   9542 non-null   float64
#  7   Price range           9542 non-null   int64
#  8   Aggregate rating      9542 non-null   float64
#  9   Rating text           9542 non-null   float64
#  10  Votes                 9542 non-null   int64
# dtypes: float64(8), int64(3)
# memory usage: 1.1 MB

# %%
df.skew()
# Out:
# Country                  3.337828
# Locality                -0.253110
# Cuisines                -0.305923
# Average Cost for two    35.461264
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating text              0.430970
# Votes                    8.813270
# dtype: float64

# %% [markdown]
# There is some skewness present in the dataset.

# %%
plt.figure(figsize=(20,20),facecolor='lightyellow')
pltno=1

for c in df:
    if pltno<=11:
        ax=plt.subplot(3,4,pltno)
        sns.boxplot(df[c],color='brown')
        plt.xlabel(c,fontsize=15)
        
    pltno+=1

# %% [markdown]
# There are outliers present in the dataset.

# %%
from scipy.stats import zscore
import numpy as np

z=np.abs(zscore(df))

z.shape
# Out:
# (9542, 11)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  20,  102,  103, ..., 9539, 9540, 9541], dtype=int64), array([10, 10, 10, ...,  0,  0,  0], dtype=int64))

# %%
 df1=df[(z<3).all(axis=1)]
df1
# Out:
#       Country  Locality  Cuisines  Average Cost for two  Currency  \
# 0         3.0      17.0    1514.0                   850       4.0
# 1         3.0      17.0    1514.0                   700       4.0
# 2         3.0      17.0    1306.0                   500       4.0
# 3         3.0     204.0    1645.0                   400       4.0
# 4         3.0     204.0    1373.0                  1000       4.0
# ...       ...       ...       ...                   ...       ...
# 8858      8.0     720.0    1821.0                    60       2.0
# 8859      8.0     850.0      83.0                    95       2.0
# 8860      8.0    1024.0      17.0                    50       2.0
# 8861      8.0    1048.0     895.0                    40       2.0
# 8862      8.0    1145.0     483.0                    75       2.0
#
#       Has Table booking  Has Online delivery  Price range  Aggregate rating  \
# 0                   0.0                  0.0            3               3.9
# ...

# %%
df.shape
# Out:
# (9542, 11)

# %%
df1.shape
# Out:
# (8590, 11)

# %%
# data loss

(9542-8590)/9542*100
# Out:
# 9.976944036889542

# %% [markdown]
#  9.97% of dataloss is a little high, but can be accepted.

# %%
df1.skew()
# Out:
# Country                 7.601446
# Locality               -0.309375
# Cuisines               -0.345319
# Average Cost for two    3.694009
# Currency               -0.870838
# Has Table booking       2.305305
# Has Online delivery     1.004879
# Price range             1.026645
# Aggregate rating       -0.881131
# Rating text             0.431043
# Votes                   3.665666
# dtype: float64

# %% [markdown]
# # 1) Taking 'Average Cost for two' as our target variable.

# %%
x=df1.drop(columns=['Average Cost for two'])
y=df1['Average Cost for two']

# %%
x
# Out:
#       Country  Locality  Cuisines  Currency  Has Table booking  \
# 0         3.0      17.0    1514.0       4.0                0.0
# 1         3.0      17.0    1514.0       4.0                0.0
# 2         3.0      17.0    1306.0       4.0                0.0
# 3         3.0     204.0    1645.0       4.0                0.0
# 4         3.0     204.0    1373.0       4.0                0.0
# ...       ...       ...       ...       ...                ...
# 8858      8.0     720.0    1821.0       2.0                0.0
# 8859      8.0     850.0      83.0       2.0                0.0
# 8860      8.0    1024.0      17.0       2.0                0.0
# 8861      8.0    1048.0     895.0       2.0                0.0
# 8862      8.0    1145.0     483.0       2.0                0.0
#
#       Has Online delivery  Price range  Aggregate rating  Rating text  Votes
# 0                     0.0            3               3.9          2.0    140
# ...

# %%
x.skew()
# Out:
# Country                7.601446
# Locality              -0.309375
# Cuisines              -0.345319
# Currency              -0.870838
# Has Table booking      2.305305
# Has Online delivery    1.004879
# Price range            1.026645
# Aggregate rating      -0.881131
# Rating text            0.431043
# Votes                  3.665666
# dtype: float64

# %%
s=['Country','Has Table booking','Currency','Has Online delivery','Price range','Votes']

# %%
from sklearn.preprocessing import PowerTransformer
yj = PowerTransformer(method = 'yeo-johnson')

# %%
x[s] = yj.fit_transform(x[s].values)

# %%
plt.figure(figsize=(20,25),facecolor='lightyellow')
pltno=1

for c in x:
    if pltno<=11:
        ax=plt.subplot(3,4,pltno)
        sns.distplot(x[c])
        plt.xlabel(c,fontsize=15)
        
    pltno+=1

# %% [markdown]
# # Standard scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_x = sc.fit_transform(x)
scaled_x
# Out:
# array([[-0.02545991, -2.14771518,  1.00192787, ...,  0.92274517,
#          0.21994613,  0.97791105],
#        [-0.02545991, -2.14771518,  1.00192787, ...,  0.65740699,
#          0.21994613,  0.61905361],
#        [-0.02545991, -2.14771518,  0.58898847, ...,  0.72374154,
#          0.21994613,  0.76660702],
#        ...,
#        [13.74636488,  1.1501371 , -1.97004464, ...,  0.85641063,
#          0.21994613,  0.13951576],
#        [13.74636488,  1.22873537, -0.2269639 , ...,  0.92274517,
#          0.21994613,  0.25291466],
#        [13.74636488,  1.54640336, -1.04490156, ...,  0.45840336,
#         -1.01774615,  0.22290017]])

# %%
xx=pd.DataFrame(scaled_x,columns=x.columns)

# %%
xx
# Out:
#         Country  Locality  Cuisines  Currency  Has Table booking  \
# 0     -0.025460 -2.147715  1.001928 -0.000313          -0.373374
# 1     -0.025460 -2.147715  1.001928 -0.000313          -0.373374
# 2     -0.025460 -2.147715  0.588988 -0.000313          -0.373374
# 3     -0.025460 -1.535304  1.262000 -0.000313          -0.373374
# 4     -0.025460 -1.535304  0.722003 -0.000313          -0.373374
# ...         ...       ...       ...       ...                ...
# 8585  13.746365  0.154559  1.611411 -8.988877          -0.373374
# 8586  13.746365  0.580300 -1.839016 -8.988877          -0.373374
# 8587  13.746365  1.150137 -1.970045 -8.988877          -0.373374
# 8588  13.746365  1.228735 -0.226964 -8.988877          -0.373374
# 8589  13.746365  1.546403 -1.044902 -8.988877          -0.373374
#
#       Has Online delivery  Price range  Aggregate rating  Rating text  \
# 0               -0.616736     1.386704          0.922745     0.219946
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['Vif values']=[variance_inflation_factor(xx.values,i)
                    for i in range(len(xx.columns))]
vif["features"]=xx.columns
vif
# Out:
#    Vif values             features
# 0    1.127733              Country
# 1    1.036057             Locality
# 2    1.019537             Cuisines
# 3    1.125690             Currency
# 4    1.338847    Has Table booking
# 5    1.170669  Has Online delivery
# 6    1.682776          Price range
# 7    4.608643     Aggregate rating
# 8    1.339337          Rating text
# 9    4.891004                Votes

# %% [markdown]
# All vif values are under 10

# %% [markdown]
# # Model building

# %%
# importing thee necessary libraries
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split,cross_val_score

# %%
models_reg=[LinearRegression(),SVR(),RandomForestRegressor(),KNeighborsRegressor(),DecisionTreeRegressor(),AdaBoostRegressor()]

# %%
maxAcc = 0
maxRS = 0

for i in range(1,60):
    xtrain,xtest,ytrain,ytest = train_test_split(xx,y,test_size = .25, random_state=i)
    lg = LinearRegression()
    lg.fit(xtrain,ytrain)
    pred = lg.predict(xtest)
    acc = r2_score(ytest,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRs=i
print("Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# Best Accuracy is: 0.6411190740534003 on Random State: 48

# %%
 x_train,x_test,y_train,y_test = train_test_split(xx,y,test_size = .25, random_state=48)

# %%
for m in models_reg:
    m.fit(x_train,y_train)
    mpred=m.predict(x_test)
    print('\033[1m','For',m,'\033[0m')
    print("R2 score :",r2_score(y_test, mpred))
    print("Mean absolute error: ", mean_absolute_error(y_test,mpred))
    print("Mean squared error: ", mean_squared_error(y_test,mpred))
    cvs=cross_val_score(m,xx,y,cv=5,scoring='r2')
    print('Cross Validation Score=',cvs.mean(),'\n')
    print('*'*85)
# Out:
#  For LinearRegression()
# R2 score : 0.6411190740534003
# Mean absolute error:  189.80503072081856
# Mean squared error:  111234.55943777664
# Cross Validation Score= 0.547732195086337
#
# *************************************************************************************
#  For SVR()
# R2 score : 0.36173001813287176
# Mean absolute error:  206.72431072624445
# Mean squared error:  197830.7430189586
# Cross Validation Score= 0.3493333488769207
#
# *************************************************************************************
#  For RandomForestRegressor()
# R2 score : 0.834617515161381
# Mean absolute error:  116.2478849472547
# Mean squared error:  51260.03225506013
# Cross Validation Score= 0.6013853079205163
#
# *************************************************************************************
#  For KNeighborsRegressor()
# R2 score : 0.7477248212722083
# Mean absolute error:  145.68277467411545
# Mean squared error:  78192.28143389199
# ...

# %% [markdown]
# RandomForest Regressor is our best model.

# %%
from sklearn.model_selection import GridSearchCV

param = {'n_estimators':[50,60,70],'max_depth': [10,15,20],
            'criterion':['mse','mae'],'min_samples_leaf': [5,10,15],
             'min_samples_split':[5,10,15,20],
             'max_features':["auto","sqrt","log2"]}
gcs=GridSearchCV(RandomForestRegressor(),param,cv=5)
gcs.fit(xtrain,ytrain)
gcs.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 15,
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 15,
#  'n_estimators': 60}

# %%
fmodel1=RandomForestRegressor(max_features='auto',criterion='mse',min_samples_leaf=5,min_samples_split=15,max_depth=20,n_estimators=60)

# %%
fmodel1.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(criterion='mse', max_depth=20, min_samples_leaf=5,
#                       min_samples_split=15, n_estimators=60)

# %%
pred1=fmodel1.predict(x_test)
acc=r2_score(y_test,pred1)
print(acc*100)
# Out:
# 90.50245191486475

# %%
# the Randomforest Regressor gives the accuracy of 90.50%

# %% [markdown]
# # saving the model

# %%
import joblib
joblib.dump(fmodel1,'avg_cost_for_two')
# Out:
# ['avg_cost_for_two']

# %% [markdown]
# # Loading the model

# %%
p = joblib.load("avg_cost_for_two")
pp=p.predict(x_test)
print(p.predict(x_test))
# Out:
# [ 632.5248706   300.97012909  263.43358311 ...  571.7133046  1299.77397839
#   642.97192329]

# %%
d1=pd.DataFrame({'predicted values':pp,'actual values':y_test})

# %%
d1
# Out:
#       predicted values  actual values
# 5589        632.524871            600
# 7881        300.970129            300
# 8072        263.433583            200
# 2199        310.163731            350
# 6804        627.848502            550
# ...                ...            ...
# 7650        269.017498            300
# 1402        256.070971            200
# 1285        571.713305            500
# 2365       1299.773978           1600
# 1585        642.971923            700
#
# [2148 rows x 2 columns]

# %% [markdown]
# # Best fit line

# %%
plt.scatter(x=y_test,y=pp,color='palegreen')
plt.plot(y_test,y_test,color='saddlebrown')
plt.title('Best Fit Line',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Best Fit Line')

# %% [markdown]
# # 2) Now taking 'Price range' as our target variable

# %%
df1
# Out:
#       Country  Locality  Cuisines  Average Cost for two  Currency  \
# 0         3.0      17.0    1514.0                   850       4.0
# 1         3.0      17.0    1514.0                   700       4.0
# 2         3.0      17.0    1306.0                   500       4.0
# 3         3.0     204.0    1645.0                   400       4.0
# 4         3.0     204.0    1373.0                  1000       4.0
# ...       ...       ...       ...                   ...       ...
# 8858      8.0     720.0    1821.0                    60       2.0
# 8859      8.0     850.0      83.0                    95       2.0
# 8860      8.0    1024.0      17.0                    50       2.0
# 8861      8.0    1048.0     895.0                    40       2.0
# 8862      8.0    1145.0     483.0                    75       2.0
#
#       Has Table booking  Has Online delivery  Price range  Aggregate rating  \
# 0                   0.0                  0.0            3               3.9
# ...

# %%
xx=df1.drop(columns=['Price range'])
yy=df1['Price range']

# %%
xx
# Out:
#       Country  Locality  Cuisines  Average Cost for two  Currency  \
# 0         3.0      17.0    1514.0                   850       4.0
# 1         3.0      17.0    1514.0                   700       4.0
# 2         3.0      17.0    1306.0                   500       4.0
# 3         3.0     204.0    1645.0                   400       4.0
# 4         3.0     204.0    1373.0                  1000       4.0
# ...       ...       ...       ...                   ...       ...
# 8858      8.0     720.0    1821.0                    60       2.0
# 8859      8.0     850.0      83.0                    95       2.0
# 8860      8.0    1024.0      17.0                    50       2.0
# 8861      8.0    1048.0     895.0                    40       2.0
# 8862      8.0    1145.0     483.0                    75       2.0
#
#       Has Table booking  Has Online delivery  Aggregate rating  Rating text  \
# 0                   0.0                  0.0               3.9          2.0
# ...

# %%
xx.skew()
# Out:
# Country                 7.601446
# Locality               -0.309375
# Cuisines               -0.345319
# Average Cost for two    3.694009
# Currency               -0.870838
# Has Table booking       2.305305
# Has Online delivery     1.004879
# Aggregate rating       -0.881131
# Rating text             0.431043
# Votes                   3.665666
# dtype: float64

# %%
xx['Average Cost for two']=np.log1p(xx['Average Cost for two'])
xx['Votes']=np.log1p(xx['Votes'])
xx['Has Table booking']=np.log1p(xx['Has Table booking'])
xx['Votes']=np.log1p(df2['Votes'])
xx['Has Online delivery']=np.log1p(xx['Has Online delivery'])

# %%
plt.figure(figsize=(20,25),facecolor='lightyellow')
pltno=1

for c in xx:
    if pltno<=10:
        ax=plt.subplot(3,4,pltno)
        sns.distplot(xx[c])
        plt.xlabel(c,fontsize=15)
        
    pltno+=1

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_x = sc.fit_transform(xx)
scaled_x
# Out:
# array([[-0.03785353, -2.14771518,  1.00192787, ...,  0.92274517,
#          0.21994613,  1.22617903],
#        [-0.03785353, -2.14771518,  1.00192787, ...,  0.65740699,
#          0.21994613,  1.53879944],
#        [-0.03785353, -2.14771518,  0.58898847, ...,  0.72374154,
#          0.21994613,  1.15163092],
#        ...,
#        [15.59492501,  1.1501371 , -1.97004464, ...,  0.85641063,
#          0.21994613,  0.12311697],
#        [15.59492501,  1.22873537, -0.2269639 , ...,  0.92274517,
#          0.21994613,  0.74384637],
#        [15.59492501,  1.54640336, -1.04490156, ...,  0.45840336,
#         -1.01774615, -0.35325101]])

# %%
xx=pd.DataFrame(scaled_x,columns=x.columns)

# %%
xx
# Out:
#         Country  Locality  Cuisines  Currency  Has Table booking  \
# 0     -0.037854 -2.147715  1.001928  0.816560           0.009202
# 1     -0.037854 -2.147715  1.001928  0.571204           0.009202
# 2     -0.037854 -2.147715  0.588988  0.146171           0.009202
# 3     -0.037854 -1.535304  1.262000 -0.135552           0.009202
# 4     -0.037854 -1.535304  0.722003  1.021980           0.009202
# ...         ...       ...       ...       ...                ...
# 8585  15.594925  0.154559  1.611411 -2.518313          -9.871178
# 8586  15.594925  0.580300 -1.839016 -1.944510          -9.871178
# 8587  15.594925  1.150137 -1.970045 -2.744871          -9.871178
# 8588  15.594925  1.228735 -0.226964 -3.021038          -9.871178
# 8589  15.594925  1.546403 -1.044902 -2.240114          -9.871178
#
#       Has Online delivery  Price range  Aggregate rating  Rating text  \
# 0               -0.373374    -0.616736          0.922745     0.219946
# ...

# %%
vif=pd.DataFrame()
vif['Vif values']=[variance_inflation_factor(xx.values,i)
                    for i in range(len(xx.columns))]
vif["features"]=xx.columns
vif
# Out:
#    Vif values             features
# 0    1.050476              Country
# 1    1.043444             Locality
# 2    1.016978             Cuisines
# 3    1.588200             Currency
# 4    1.051233    Has Table booking
# 5    1.422430  Has Online delivery
# 6    1.113569          Price range
# 7    1.402505     Aggregate rating
# 8    1.150810          Rating text
# 9    1.022207                Votes

# %% [markdown]
# All the vif values are under 10

# %%
yy.value_counts()
# Out:
# 1    4296
# 2    2846
# 3    1056
# 4     392
# Name: Price range, dtype: int64

# %% [markdown]
# Data in target variable is imbalanced

# %%
from imblearn.over_sampling import SMOTE
smt= SMOTE(random_state=34)
train_x,train_y=smt.fit_resample(xx,yy)
train_y.value_counts()
# Out:
# 3    4296
# 2    4296
# 4    4296
# 1    4296
# Name: Price range, dtype: int64

# %%
df_new=pd.DataFrame(data=train_x)
df_new['Price range']=train_y
ndf1=df_new
ndf1
# Out:
#         Country  Locality  Cuisines  Currency  Has Table booking  \
# 0     -0.037854 -2.147715  1.001928  0.816560           0.009202
# 1     -0.037854 -2.147715  1.001928  0.571204           0.009202
# 2     -0.037854 -2.147715  0.588988  0.146171           0.009202
# 3     -0.037854 -1.535304  1.262000 -0.135552           0.009202
# 4     -0.037854 -1.535304  0.722003  1.021980           0.009202
# ...         ...       ...       ...       ...                ...
# 17179 -0.037854 -0.985173 -0.943754  1.949782           0.009202
# 17180 -0.037854 -0.421166 -1.241507  2.087372           0.009202
# 17181 -0.037854  0.477177  0.927715  2.662598           0.009202
# 17182 -0.037854 -1.516241  0.803251  1.312896           0.009202
# 17183 -0.037854 -0.750008 -0.427845  2.599173           0.009202
#
#        Has Online delivery  Price range  Aggregate rating  Rating text  \
# 0                -0.373374            3          0.922745     0.219946
# ...

# %%
x=ndf1.drop(columns=['Price range'])
y=ndf1['Price range']

# %%
y.value_counts()
# Out:
# 3    4296
# 2    4296
# 4    4296
# 1    4296
# Name: Price range, dtype: int64

# %% [markdown]
# # Model building

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
models=[LogisticRegression(),RandomForestClassifier(),KNeighborsClassifier(),DecisionTreeClassifier(), SVC()]

# %%
maxAccu=0
maxRS=0
lg=LogisticRegression()
for i in range(20,40):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.25)
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best Accuracy score is', maxAccu , 'on random state', maxRS)
# Out:
# Best Accuracy score is 0.9134078212290503 on random state 33

# %%
# thee model gives best accuracy at random state 33

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .25, random_state=33)

# %%
for m in models:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('\033[1m','For' ,m,'\033[0m','Accuracy score is: ',accuracy_score(y_test,predm))
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,predm))
    print ('\n','Classification Report:','\n',classification_report(y_test,predm))
    cvs=cross_val_score(m,x,y)
    print('Cross Validation Score=',cvs.mean(),'\n')
    print('*'*80)
# Out:
#  For LogisticRegression()  Accuracy score is:  0.9134078212290503
#
#  Confusion matrix:
#  [[ 978   83    0    0]
#  [  13  985   72    0]
#  [   7   68  952   74]
#  [   0   10   45 1009]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.98      0.92      0.95      1061
#            2       0.86      0.92      0.89      1070
#            3       0.89      0.86      0.88      1101
#            4       0.93      0.95      0.94      1064
#
#     accuracy                           0.91      4296
#    macro avg       0.92      0.91      0.91      4296
# weighted avg       0.92      0.91      0.91      4296
#
# Cross Validation Score= 0.8964154887763547
#
# ********************************************************************************
#  For RandomForestClassifier()  Accuracy score is:  0.9844040968342644
#
#  Confusion matrix:
#  [[1060    1    0    0]
#  [  17 1050    3    0]
#  [   0   22 1071    8]
# ...

# %%
# RandomForest classifier is our best model.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
param = {'max_features':['auto','sqrt','log2'],
      'max_depth':[5,10,15,20,25],
      'criterion':['gini','entropy']}
gcs=GridSearchCV(RandomForestClassifier(),param,cv=5)
gcs.fit(x_train,y_train)
gcs.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'auto'}

# %%
fmodel2=RandomForestClassifier(max_features='auto',criterion='gini',max_depth=15)
fmodel2.fit(x_train,y_train)
pred=fmodel2.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 98.27746741154563

# %%
#  the randomforest classifier gives the accuracy of 98.27%

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(fmodel2,'price_range')
# Out:
# ['price_range']

# %% [markdown]
# # Loading the model

# %%
m = joblib.load("price_range")
pp=m.predict(x_test)
print(m.predict(x_test))
# Out:
# [1 3 1 ... 1 3 4]

# %%
d=pd.DataFrame({'predicted values':pp,'actual values':y_test})
d
# Out:
#        predicted values  actual values
# 8084                  1              1
# 12851                 3              3
# 3329                  1              1
# 13839                 4              4
# 14930                 4              4
# ...                 ...            ...
# 8883                  2              2
# 20                    4              4
# 6064                  1              1
# 12547                 3              3
# 17070                 4              4
#
# [4296 rows x 2 columns]

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_test, pp)
cm_display = ConfusionMatrixDisplay(cm).plot(cmap='rainbow')
plt.grid(False)
